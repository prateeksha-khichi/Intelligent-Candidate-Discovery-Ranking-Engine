# %% [markdown]
# # Redrob Candidate Ranking - Sandbox
# This notebook clones the repository and runs the ranking algorithm on a small 50-candidate sample to demonstrate the offline evaluation pipeline.

# %%
# !git clone https://github.com/prateeksha-khichi/Intelligent-Candidate-Discovery-Ranking-Engine.git
# %cd Intelligent-Candidate-Discovery-Ranking-Engine
# !pip install -r requirements.txt -q
import os
os.environ['PYTHONPATH'] = '/content/Intelligent-Candidate-Discovery-Ranking-Engine'

# %%
# Run the ranking algorithm in sample mode
# !python -m src.ranking.rank_candidates --sample
